# %%
import streamlit as st
import pandas as pd
import urllib
import json
from helpers import *
# Out:
# 2025-03-03 03:23:05.473 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
station_url = 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_status.json'
latlon_url = 'https://tor.publicbikesystem.net/ube/gbfs/v1/en/station_information'

# %%
df1 = query_station_status(station_url)
# Out:
# 2025-03-03 03:23:13.112 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-03-03 03:23:13.114 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-03 03:23:13.407
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Admin\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-03-03 03:23:13.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-03 03:23:13.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-03 03:23:13.920 Thread 'Thread-25': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-03 03:23:13.938 Thread 'Thread-25': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-03 03:23:16.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-03 03:23:16.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df2 = get_station_latlon(latlon_url)

# %%
join_latlon(df1,df2)
# Out:
#     station_id  num_bikes_available       num_bikes_available_types  \
# 0         7000                   13  {'mechanical': 13, 'ebike': 0}
# 1         7001                    6   {'mechanical': 6, 'ebike': 0}
# 2         7002                   11   {'mechanical': 7, 'ebike': 4}
# 3         7003                    0   {'mechanical': 0, 'ebike': 0}
# 4         7005                    5   {'mechanical': 5, 'ebike': 0}
# ..         ...                  ...                             ...
# 862       8016                    5   {'mechanical': 5, 'ebike': 0}
# 863       8017                    3   {'mechanical': 3, 'ebike': 0}
# 864       8018                    5   {'mechanical': 5, 'ebike': 0}
# 865       8019                    0   {'mechanical': 0, 'ebike': 0}
# 866       8020                    8   {'mechanical': 8, 'ebike': 0}
#
#      num_bikes_disabled  num_docks_available  num_docks_disabled  \
# 0                     0                   32                   0
# 1                     1                   16                   0
# 2                     0                    5                   1
# 3                     0                   14                   1
# 4                     0                   17                   0
# ..                  ...                  ...                 ...
# 862                   1                   17                   0
# 863                   0                   12                   0
# 864                   1                    9                   0
# 865                   0                   15                   0
# 866                   0                    0                   1
#
#           last_reported  is_charging_station      status  is_installed  \
# 0   2025-03-02 22:22:42                False  IN_SERVICE             1
# 1   2025-03-02 22:21:44                 True  IN_SERVICE             1
# 2   2025-03-02 22:22:27                False  IN_SERVICE             1
# 3   2025-03-02 22:21:34                False  IN_SERVICE             1
# 4   2025-03-02 22:21:19                False  IN_SERVICE             1
# ..                  ...                  ...         ...           ...
# 862 2025-03-02 22:21:44                False  IN_SERVICE             1
# 863 2025-03-02 22:21:18                False  IN_SERVICE             1
# 864 2025-03-02 22:21:51                False  IN_SERVICE             1
# 865 2025-03-02 22:22:11                False  IN_SERVICE             1
# 866 2025-03-02 22:22:23                False  IN_SERVICE             1
#
#      is_renting  is_returning traffic  mechanical  ebike        lat        lon
# 0             1             1    None          13      0  43.639832 -79.395954
# 1             1             1    None           6      0  43.664964 -79.383550
# 2             1             1    None           7      4  43.667131 -79.399555
# 3             1             1    None           0      0  43.667018 -79.402796
# 4             1             1    None           5      0  43.648001 -79.383177
# ..          ...           ...     ...         ...    ...        ...        ...
# 862           1             1    None           5      0  43.642499 -79.372858
# 863           1             1    None           3      0  43.725345 -79.297687
# 864           1             1    None           5      0  43.658977 -79.347153
# 865           1             1    None           0      0  43.680567 -79.390830
# 866           1             1    None           8      0  43.646568 -79.407687
#
# [867 rows x 17 columns]
